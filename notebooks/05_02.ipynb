# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0                                           ['come']
# 1                   ['im', 'home', 'please', 'call']
# 2                          ['yup', 'ì', 'comin', '']
# 3                                      ['k', 'sent']
# 4  ['eh', 'ur', 'laptop', 'got', 'stock', 'lei', ...

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'come': 2005,
#  'im': 3795,
#  'home': 3637,
#  'please': 5560,
#  'call': 1680,
#  'yup': 8198,
#  'comin': 2012,
#  'sent': 6347,
#  'eh': 2674,
#  'ur': 7571,
#  'laptop': 4233,
#  'got': 3340,
#  'stock': 6832,
#  'lei': 4295,
#  'say': 6254,
#  'mon': 4832,
#  'muz': 4935,
#  'take': 7045,
#  'look': 4423,
#  'pls': 5567,
#  'give': 3276,
#  'food': 3055,
#  'preferably': 5689,
#  'pap': 5373,
#  'slowly': 6572,
#  'loads': 4392,
#  'sugar': 6935,
#  'hour': 3683,
#  'water': 7786,
#  'wanna': 7760,
#  'gym': 3432,
#  'harri': 3492,
#  'hi': 3580,
#  'test': 7137,
#  'ltgt': 4487,
#  'rd': 5907,
#  'wont': 7973,
#  'anything': 1066,
#  'de': 2298,
#  'send': 6337,
#  'naughty': 4979,
#  'pix': 5532,
#  'aight': 945,
#  'fuck': 3157,
#  'ill': 3792,
#  'get': 3248,
#  'later': 4248,
#  'dude': 2607,
#  'ive': 3961,
#  'seeing': 6312,
#  'lotta': 4449,
#  'corvettes': 2122,
#  'lately': 4246,
#  'congrats': 2069,
#  'year': 8125,
#  'special': 6700,
#  'cinema': 1919,
#  'pass': 5408,
#  '09061209465': 184,
#  'suprman': 6976,
#  'matrix3': 4634,
#  'starwars3': 6799,
#  'etc': 2770,
#  'free': 3108,
#  'bx420ip45we': 1660,
#  '150pm': 317,
#  'dont': 2535,
#  'miss': 4775,
#  'nightswe': 5048,
#  'nt': 5138,
#  'staying': 6808,
#  'port': 5630,
#  'step': 6816,
#  'liaotoo': 4319,
#  'ex': 2812,
#  'babe': 1254,
#  'likely': 4342,
#  'bed': 1357,
#  'sorry': 6662,
#  'tonight': 7340,
#  'really': 5927,
#  'see': 6310,
#  'tomorrow': 7329,
#  'love': 4459,
#  'xxx': 8102,
#  'didt': 2426,
#  'play': 5550,
#  'one': 5241,
#  'day': 2287,
#  'last': 4241,
#  'know': 4174,
#  'even': 2782,
#  'though': 7223,
#  'good': 3321,
#  'team': 7098,
#  'like': 4340,
#  'india': 3838,
#  'thats': 7172,
#  'shame': 6392,
#  'maybe': 4647,
#  'cld': 1935,
#  'meet': 4671,
#  'hrs': 3703,
#  'tomo': 7326,
#  'ok': 5214,
#  'cool': 2108,
#  'ya': 8111,
#  'email': 2694,
#  'id': 3769,
#  'soon': 6651,
#  'gonna': 3320,
#  'death': 2319,
#  'leave': 4281,
#  'note': 5109,
#  'says': 6258,
#  'robs': 6128,
#  'fault': 2914,
#  'avenge': 1226,
#  'looking': 4427,
#  'outside': 5323,
#  'office': 5193,
#  'carlos': 1752,
#  'pick': 5508,
#  'yeah': 8124,
#  'set': 6363,
#  'update': 7558,
#  'face': 2862,
#  'book': 1497,
#  'status': 6804,
#  'frequently': 3124,
#  'ìï': 8217,
#  'predict': 5684,
#  'wat': 7781,
#  'time': 7262,
#  'ìll': 8216,
#  'finish': 2988,
#  'buying': 1653,
#  'bugis': 1620,
#  'oso': 5305,
#  'near': 4985,
#  'wonder': 7969,
#  'online': 5248,
#  'gone': 3318,
#  'net': 5011,
#  'cafe': 1669,
#  'phone': 5496,
#  'recharged': 5950,
#  'friends': 3136,
#  'think': 7205,
#  'boytoy': 1544,
#  'oh': 5208,
#  'unintentionally': 7533,
#  'bad': 1268,
#  'timing': 7271,
#  'great': 3370,
#  'fingers': 2987,
#  'trains': 7389,
#  'along': 988,
#  'fifteen': 2954,
#  'min': 4749,
#  'warning': 7772,
#  'shall': 6391,
#  'pouch': 5653,
#  'sir': 6509,
#  'need': 4995,
#  'axis': 1243,
#  'bank': 1291,
#  'account': 845,
#  'address': 875,
#  'much': 4905,
#  'blackberry': 1442,
#  'bold2': 1488,
#  'nigeria': 5040,
#  'right': 6103,
#  'ahmad': 938,
#  'late': 4243,
#  'tellmiss': 7115,
#  'way': 7795,
#  'part': 5396,
#  'nothing': 5112,
#  'thesmszonecom': 7197,
#  'lets': 4311,
#  'anonymous': 1045,
#  'masked': 4616,
#  'messagesim': 4721,
#  'sending': 6339,
#  'message': 4714,
#  'theredo': 7189,
#  'potential': 5651,
#  'abuse': 828,
#  'reckon': 5953,
#  'arrange': 1139,
#  'transport': 7398,
#  'cant': 1726,
#  'thanks': 7158,
#  'yay': 8121,
#  'wait': 7734,
#  'party': 5404,
#  'together': 7311,
#  'want': 7762,
#  'hear': 3518,
#  'morning': 4857,
#  'show': 6454,
#  'colours': 2001,
#  'euro': 2773,
#  '2004': 384,
#  '241': 400,
#  'offer': 5188,
#  'england': 2724,
#  'flag': 3009,
#  '3lions': 511,
#  'tone': 7333,
#  'click': 1944,
#  'following': 3049,
#  'service': 6359,
#  'info': 3850,
#  'hurry': 3741,
#  'soup': 6680,
#  'done': 2532,
#  'night': 5042,
#  'ended': 2712,
#  'another': 1047,
#  'may': 4645,
#  'smile': 6584,
#  'sunny': 6956,
#  'rays': 5901,
#  'leaves': 4282,
#  'worries': 8000,
#  'blue': 1474,
#  'bay': 1323,
#  'gud': 3408,
#  'mrng': 4883,
#  'havent': 3504,
#  'next': 5028,
#  'said': 6208,
#  'aww': 1241,
#  'first': 2999,
#  'missed': 4776,
#  'without': 7943,
#  'asking': 1162,
#  'private': 5733,
#  '2003': 383,
#  'statement': 6801,
#  'shows': 6462,
#  '800': 695,
#  'unredeemed': 7546,
#  'points': 5599,
#  '08718738002': 144,
#  'identifier': 3776,
#  'code': 1978,
#  '48922': 561,
#  'expires': 2844,
#  '211104': 392,
#  'ni8swt': 5032,
#  'drmstake': 2588,
#  'care': 1739,
#  'list': 4369,
#  'buyers': 1652,
#  'godi': 3302,
#  'amp': 1014,
#  'youclean': 8166,
#  'heart': 3521,
#  'bloodsend': 1466,
#  'ten': 7123,
#  'people': 5452,
#  'miracle': 4770,
#  'itplspls': 3952,
#  'tried': 7414,
#  'contact': 2082,
#  'reply': 6037,
#  'video': 7658,
#  'handset': 3465,
#  '750': 673,
#  'anytime': 1069,
#  'networks': 5016,
#  'mins': 4761,
#  'unlimited': 7542,
#  'text': 7142,
#  'camcorder': 1707,
#  '08000930705': 46,
#  'becoz': 1355,
#  'jan': 3983,
#  'whn': 7889,
#  'al': 958,
#  'post': 5642,
#  'ofice': 5202,
#  'holiday': 3631,
#  'cn': 1965,
#  'go': 3294,
#  'fr': 3099,
#  'oficegot': 5203,
#  'duffer': 2610,
#  'vote': 7704,
#  'wherever': 7882,
#  'guides': 3419,
#  'dad': 2241,
#  'gets': 3252,
#  'work': 7985,
#  'ask': 1158,
#  'crazy': 2167,
#  'questions': 5846,
#  'claim': 1924,
#  '200': 380,
#  'shopping': 6436,
#  'spree': 6754,
#  '08717895698': 127,
#  'mobstorequiz10ppm': 4815,
#  'back': 1264,
#  'bit': 1433,
#  'long': 4419,
#  'cos': 2123,
#  'accident': 838,
#  'a30': 809,
#  'divert': 2490,
#  'via': 7650,
#  'wadebridgei': 7727,
#  'brilliant': 1572,
#  'weekend': 7827,
#  'speak': 6698,
#  'lots': 4447,
#  'yes': 8136,
#  'lap': 4232,
#  'room': 6141,
#  'days': 2291,
#  'didnt': 2423,
#  'shut': 6470,
#  'liao': 4317,
#  'mark': 4602,
#  'taking': 7050,
#  'forever': 3068,
#  'prescription': 5701,
#  'pain': 5357,
#  'coming': 2013,
#  'sometimes': 6637,
#  'put': 5824,
#  'walls': 7753,
#  'around': 1135,
#  'heartsnot': 3525,
#  'safe': 6203,
#  'getting': 3256,
#  'hurt': 3742,
#  'find': 2979,
#  'cares': 1747,
#  'enough': 2732,
#  'break': 1558,
#  'closer': 1953,
#  'goodnoon': 3330,
#  'within': 7942,
#  'abt': 825,
#  'making': 4572,
#  'pics': 5512,
#  'bigger': 1413,
#  'shit': 6419,
#  'thought': 7224,
#  'trip': 7415,
#  'loooooool': 4430,
#  'makes': 4569,
#  'sense': 6343,
#  'grins': 3382,
#  'sofa': 6616,
#  'reference': 5970,
#  'sleep': 6546,
#  'couch': 2131,
#  'link': 4359,
#  'wasnt': 7776,
#  'went': 7851,
#  'celebration': 1795,
#  'rents': 6026,
#  'annoying': 1044,
#  'isnt': 3934,
#  'spent': 6716,
#  'afternoon': 912,
#  'casualty': 1772,
#  'means': 4659,
#  'stuff42moro': 6892,
#  'includes': 3825,
#  'sheets': 6402,
#  'camera': 1709,
#  'awarded': 1237,
#  'sipix': 6507,
#  'digital': 2441,
#  '09061221066': 187,
#  'fromm': 3151,
#  'landline': 4223,
#  'delivery': 2360,
#  '28': 418,
#  'girls': 3273,
#  'always': 1000,
#  'selfish': 6328,
#  'pa': 5346,
#  'thank': 7157,
#  'gsoh': 3402,
#  'spam': 6693,
#  'ladiesu': 4211,
#  'could': 2134,
#  'male': 4575,
#  'gigolo': 3265,
#  'join': 4028,
#  'uks': 7498,
#  'fastest': 2906,
#  'growing': 3393,
#  'mens': 4697,
#  'club': 1958,
#  'oncall': 5239,
#  'mjzgroup': 4794,
#  '087143423992stop': 106,
#  'stop': 6841,
#  'msgå': 4896,
#  '150rcvd': 335,
#  'probably': 5742,
#  'earlier': 2625,
#  'goodmorning': 3326,
#  'today': 7302,
#  'many': 4593,
#  'seems': 6317,
#  'sight': 6481,
#  'remain': 6003,
#  'till': 7260,
#  'maintain': 4565,
#  'life': 4328,
#  'ends': 2715,
#  'cr': 2154,
#  'da': 2237,
#  'usualiam': 7601,
#  'fine': 2982,
#  'happy': 3484,
#  'well': 7843,
#  'greatest': 3373,
#  'courage': 2144,
#  'earth': 2631,
#  'bear': 1344,
#  'defeat': 2340,
#  'losing': 4441,
#  'heartgn': 3523,
#  'tc': 7085,
#  'hey': 3574,
#  'sat': 6240,
#  'going': 3309,
#  'intro': 3901,
#  'pilates': 5521,
#  'kickboxing': 4129,
#  'anywhere': 1072,
#  'damn': 2252,
#  'job': 4022,
#  'hunting': 3738,
#  'apart': 1074,
#  'told': 7318,
#  'yesterday': 8148,
#  'greatbye': 3372,
#  'stitch': 6831,
#  'trouser': 7422,
#  'check': 1847,
#  'audreys': 1204,
#  '08714712388': 108,
#  '10am7pm': 266,
#  'cost': 2125,
#  '10p': 269,
#  'physics': 5505,
#  'rounderso': 6151,
#  'required': 6046,
#  '1000': 254,
#  'cash': 1762,
#  '2000': 381,
#  'prize': 5735,
#  'call09050000327': 1681,
#  'hello': 3538,
#  'bored': 1507,
#  'inever': 3845,
#  'tv': 7460,
#  'tell': 7113,
#  'something': 6634,
#  'exciting': 2821,
#  'happened': 3477,
#  'idea': 3772,
#  'make': 4568,
#  'welcome': 7841,
#  'age': 920,
#  'gender': 3233,
#  'begin': 1369,
#  'eg': 2666,
#  '24m': 403,
#  'dai': 2248,
#  'naal': 4946,
#  'eruku': 2755,
#  'princess': 5725,
#  'wuld': 8040,
#  'baby': 1258,
#  'alone': 987,
#  'mite': 4788,
#  'donåõt': 2539,
#  'everyboy': 2793,
#  'needs': 5000,
#  'lady': 4212,
#  'xxxxxxxx': 8107,
#  'choose': 1902,
#  'videos': 7662,
#  'smsshsexnetun': 6601,
#  'fgkslpopw': 2949,
#  'fgkslpo': 2948,
#  'anyway': 1070,
#  'evenings': 2784,
#  'tones': 7334,
#  'replying': 6039,
#  'mix': 4792,
#  'mytonecomenjoy': 4943,
#  'html': 3705,
#  'terms': 7131,
#  'gbp450week': 3220,
#  'mfl': 4730,
#  'arun': 1150,
#  'transfr': 7397,
#  'amt': 1019,
#  'forgot': 3076,
#  'dan': 2253,
#  'reminded': 6012,
#  'hope': 3659,
#  'guys': 3428,
#  'fun': 3170,
#  'lovely': 4463,
#  'chance': 1812,
#  '150': 307,
#  'worth': 8006,
#  'discount': 2475,
#  'voucherstext': 7708,
#  '85023': 742,
#  'nowsavamobmember': 5131,
#  'offers': 5191,
#  'mobile': 4807,
#  'cs': 2195,
#  '08717898035': 128,
#  '300': 474,
#  'sub': 6905,
#  '16': 341,
#  'remove': 6017,
#  'txt': 7472,
#  'sef': 6320,
#  'dey': 2405,
#  'laugh': 4253,
#  'meanwhile': 4661,
#  'hows': 3696,
#  'darling': 2271,
#  'anjie': 1036,
#  'noe': 5075,
#  'files': 2965,
#  'computers': 2048,
#  'brother': 1592,
#  'problem': 5743,
#  'thing': 7203,
#  'diddy': 2422,
#  'neighbor': 5006,
#  'comes': 2009,
#  'toothpaste': 7353,
#  'every': 2789,
#  'quick': 5848,
#  'bare': 1298,
#  'multimedia': 4911,
#  'kind': 4141,
#  'train': 7385,
#  'asthma': 1174,
#  'attack': 1187,
#  'nxt': 5159,
#  'half': 3451,
#  'hr': 3701,
#  'driving': 2586,
#  'sure': 6978,
#  'park': 5391,
#  'quite': 5851,
#  'film': 2970,
#  'yet': 8149,
#  'would': 8010,
#  'ip': 3914,
#  'considering': 2077,
#  'computer': 2047,
#  'minecraft': 4755,
#  'server': 6358,
#  'stalking': 6780,
#  'evening': 2783,
#  'roger': 6135,
#  'god': 3301,
#  'google': 3334,
#  'nearby': 4986,
#  'cliffs': 1945,
#  'licks': 4324,
#  'center': 1798,
#  'tootsie': 7354,
#  'pop': 5625,
#  'iouri': 3913,
#  'story': 6855,
#  'times': 7265,
#  'already': 990,
#  'phones': 5499,
#  'price': 5718,
#  'line': 4351,
#  'rental': 6023,
#  '12': 282,
#  'mths': 4902,
#  '500': 591,
#  'cross': 2185,
#  'ntwk': 5142,
#  '100': 253,
#  'txts': 7478,
#  'mobileupd8': 4811,
#  '08001950382': 48,
#  'call2optout674': 1683,
#  'roommates': 6144,
#  'took': 7346,
#  'sad': 6200,
#  'man': 4578,
#  'week': 7825,
#  'bday': 1341,
#  'wife': 7901,
#  'wish': 7933,
#  'parents': 5386,
#  'kids': 4134,
#  'colleagues': 1990,
#  'entered': 2734,
#  'cabin': 1667,
#  'boss': 1513,
#  'felt': 2938,
#  'askd': 1159,
#  'lunch': 4501,
#  'invited': 3907,
#  'apartment': 1075,
#  'mind': 4751,
#  'bedroom': 1359,
#  'minute': 4767,
#  'sed': 6309,
#  'sexy': 6375,
#  'mood': 4849,
#  'came': 1708,
#  'minuts': 4769,
#  'latr': 4252,
#  'wid': 7898,
#  'caken': 1672,
#  'kidz': 4135,
#  'screaming': 6283,
#  'surprise': 6985,
#  'waiting': 7738,
#  'naked': 4952,
#  'gosh': 3337,
#  'spose': 6749,
#  'better': 1398,
#  'urgent': 7574,
#  '09061213237': 185,
#  '5000': 592,
#  'await': 1233,
#  'collection': 1994,
#  'sae': 6201,
#  'po': 5577,
#  'box': 1525,
#  '177': 345,
#  'm227xy': 4522,
#  'buns': 1630,
#  'adore': 885,
#  'loverboy': 4467,
#  'remember': 6006,
#  'sister': 6515,
#  'law': 4260,
#  'meatballs': 4663,
#  'world': 7993,
#  'running': 6183,
#  'stillmaybe': 6829,
#  'feeling': 2933,
#  'sameso': 6222,
#  'itor': 3951,
#  'admiti': 884,
#  'madthen': 4549,
#  'correctionor': 2119,
#  'let': 4310,
#  'lifeand': 4329,
#  'keep': 4106,
#  'worldmay': 7995,
#  'also': 995,
#  'runninglets': 6184,
#  'run': 6182,
#  'congratulations': 2070,
#  'either': 2678,
#  'yrs': 8190,
#  'supply': 6969,
#  'cds': 1788,
#  'virgin': 7680,
#  'records': 5959,
#  'mystery': 4942,
#  'gift': 3263,
#  'guaranteed': 3406,
#  '09061104283': 183,
#  'tscs': 7438,
#  'wwwsmsconet': 8075,
#  'approx': 1103,
#  '3mins': 514,
#  'cooking': 2107,
#  'dinner': 2453,
#  'company': 2024,
#  'name': 4955,
#  'saibaba': 6207,
#  'colany': 1985,
#  'hospital': 3674,
#  'return': 6083,
#  'cramps': 2161,
#  'stopped': 6845,
#  'month': 4845,
#  'chocolate': 1899,
#  'weed': 7823,
#  'alcohol': 964,
#  'gr8': 3353,
#  'poly': 5607,
#  'mobs': 4813,
#  'direct': 2458,
#  '2u': 462,
#  'rply': 6160,
#  'title': 7281,
#  '8007': 698,
#  'breathe1': 1564,
#  'titles': 7282,
#  'crazyin': 2168,
#  'sleepingwith': 6550,
#  'finest': 2985,
#  'ymca': 8157,
#  'getzedcouk': 3257,
#  'pobox365o4w45wq': 5586,
#  '300p': 478,
#  'sfrom': 6380,
#  'training': 7387,
#  'manual': 4592,
#  'tech': 7104,
#  'processits': 5755,
#  'password': 5416,
#  'reset': 6056,
#  'troubleshooting': 7421,
#  'aathilove': 813,
#  'lot': 4444,
#  'lor': 4435,
#  'sony': 6648,
#  'ericsson': 2748,
#  'salesman': 6215,
#  'shuhui': 6468,
#  'gd': 3223,
#  'use': 7588,
#  'solve': 6624,
#  'case': 1761,
#  'found': 3092,
#  'murdered': 4924,
#  'ltdecimalgt': 4485,
#  '1his': 360,
#  'called': 1693,
#  'police': 5604,
#  '2police': 457,
#  'questioned': 5845,
#  'everyone': 2795,
#  '3wife': 524,
#  'siri': 6510,
#  'sleeping': 6548,
#  'murder': 4923,
#  'place': 5535,
#  '4cook': 564,
#  '5gardener': 608,
#  'picking': 5510,
#  'vegetables': 7636,
#  '6housemaid': 654,
#  '7children': 685,
#  '8neighbour': 785,
#  'marriage': 4608,
#  'arrested': 1141,
#  'murderer': 4925,
#  'immediately': 3805,
#  'whos': 7892,
#  'reason': 5930,
#  'new': 5022,
#  'years': 8126,
#  'eve': 2779,
#  'boyfriend': 1542,
#  'si': 6472,
#  'smith': 6589,
#  'waste': 7778,
#  'gayle': 3214,
#  'hmv': 3620,
#  'bonus': 1494,
#  'pounds': 5656,
#  'genuine': 3241,
#  'vouchers': 7707,
#  'answer': 1050,
#  'easy': 2638,
#  '86688': 750,
#  'infowww100percentrealcom': 3857,
#  '1st': 370,
#  'no1': 5064,
#  'nokia': 5084,
#  '8077': 708,
#  'txting': 7475,
#  'mates': 4626,
#  'wwwgetzedcouk': 8057,
#  'pobox': 5578,
#  '36504': 496,
#  'w45wq': 7722,
#  'norm150ptone': 5103,
#  'wats': 7792,
#  'dear': 2308,
#  'reache': 5909,
#  'white': 7888,
#  'fudge': 3162,
#  'oreos': 5294,
#  'stores': 6852,
#  'knowthis': 4178,
#  'tirunelvai': 7276,
#  'uncomfortable': 7512,
#  'tour': 7374,
#  'curious': 2214,
#  'dis': 2465,
#  'sweater': 7005,
#  'mango': 4590,
#  'size': 6525,
#  'irritating': 3926,
#  'esplanade': 2765,
#  'giving': 3279,
#  'lift': 4335,
#  'car': 1734,
#  'mobiles': 4808,
#  'must': 4930,
#  '89545': 775,
#  'collect': 1991,
#  'todayfrom': 7304,
#  'www4tcbiz': 8044,
#  '2optout': 454,
#  '08718726270150gbpmtmsg18': 134,
#  'valentines': 7617,
#  'win': 7914,
#  'quiz': 5854,
#  'partner': 5401,
#  'lifetime': 4332,
#  '83600': 733,
#  '150pmsg': 321,
#  'rcvd': 5906,
#  'custcare08718720201': 2221,
#  'meeting': 4674,
#  'glad': 3281,
#  'totally': 7368,
#  'disagreeable': 2466,
#  'lol': 4412,
#  'goodmorningmy': 3327,
#  'grandfather': 3361,
#  'expiredso': 2843,
#  'less': 4306,
#  'problematic': 5744,
#  'feel': 2931,
#  'definite': 2342,
#  'nos': 5107,
#  'booking': 1499,
#  'fri': 3128,
#  'ever': 2788,
#  'angry': 1033,
#  'misbehaved': 4772,
#  'plz': 5574,
#  'slap': 6544,
#  'urself': 7583,
#  'bcoz': 1337,
#  'basically': 1309,
#  'til': 7259,
#  'frying': 3155,
#  'pan': 5364,
#  'cheap': 1842,
#  'perhaps': 5461,
#  'silly': 6491,
#  'deep': 2334,
#  'sigh': 6479,
#  'surprised': 6986,
#  'wkend': 7949,
#  'journey': 4048,
#  'terrible': 7133,
#  'wk': 7948,
#  'huge': 3720,
#  'log': 4403,
#  'marking': 4605,
#  'cuz': 2233,
#  'ibored': 3762,
#  'study': 6888,
#  'goodnight': 3328,
#  'fix': 3005,
#  'ready': 5917,
#  'wake': 7741,
#  'dearly': 2313,
#  'cutie': 2231,
#  'goes': 3306,
#  'wales': 7743,
#  'kinda': 4142,
#  'hills': 3591,
#  'still': 6828,
#  'avent': 1227,
#  'killed': 4137,
#  'squeeeeeze': 6762,
#  'christmas': 1910,
#  'hug': 3719,
#  'lik': 4339,
#  'frndshp': 3147,
#  'den': 2363,
#  'cute': 2228,
#  'luvd': 4508,
#  'lucky': 4495,
#  'none': 5092,
#  'hate': 3498,
#  'might': 4739,
#  'class': 1931,
#  'early': 2627,
#  'review': 6091,
#  'fantastic': 2897,
#  'ngage': 5029,
#  'game': 3195,
#  'deck': 2329,
#  'wwwcnupdatescomnewsletter': 8052,
#  'unsubscribe': 7552,
#  'alerts': 968,
#  'word': 7980,
#  'birth': 1429,
#  '8lb': 783,
#  '7oz': 688,
#  'mother': 4863,
#  'brilliantly': 1573,
#  'broke': 1586,
#  'amount': 1013,
#  'small': 6575,
#  'somebody': 6627,
#  'website': 7814,
#  'hold': 3628,
#  'em': 2693,
#  'using': 7597,
#  'spacebucks': 6689,
#  'never': 5018,
#  'intention': 3887,
#  'rather': 5896,
#  'clean': 1936,
#  'visitors': 7687,
#  'best': 1390,
#  'choice': 1900,
#  'wanted': 7764,
#  'embarassed': 2696,
#  'youd': 8167,
#  'friend': 3134,
#  'wants': 7766,
#  'drop': 2589,
#  'buy': 1650,
#  'everything': 2798,
#  'else': 2691,
#  'uncles': 7511,
#  'atlanta': 1181,
#  'semester': 6334,
#  'winner': 7924,
#  'mr': 4881,
#  'foley': 3044,
#  'ipod': 3919,
#  'prizes': 5737,
#  'eye': 2857,
#  'visit': 7685,
#  'wwwwin82050couk': 8084,
#  'shes': 6408,
#  'messages': 4720,
#  'forget': 3071,
#  'feels': 2934,
#  'quiet': 5849,
#  'beth': 1396,
#  'aunts': 1209,
#  'charlie': 1829,
#  'working': 7989,
#  'helen': 3534,
#  'mo': 4803,
#  'boltblue': 1490,
#  '150p': 313,
#  'mono': 4843,
#  'poly3': 5609,
#  'cha': 1804,
#  'slide': 6558,
#  'slow': 6569,
#  'jamz': 3982,
#  'toxic': 7377,
#  'holla': 3633,
#  'watever': 7787,
#  'relation': 5993,
#  'built': 1623,
#  'remains': 6004,
#  'atlast': 1182,
#  'iz': 3963,
#  'lonlines': 4421,
#  'lotz': 4452,
#  'memories': 4694,
#  'selected': 6324,
#  'thanx': 7163,
#  'weåõve': 7868,
#  '2geva': 434,
#  'bin': 1423,
#  'mint': 4765,
#  'uxxxx': 7611,
#  'understand': 7518,
#  'awesome': 1239,
#  'delete': 2353,
#  '447801259231': 546,
#  'secret': 6301,
#  'admirer': 881,
#  'ufind': 7487,
#  'rreveal': 6162,
#  'thinks': 7209,
#  'specialcall': 6701,
#  '09058094597': 174,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8226 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred=rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.796 / Accuracy: 0.972
